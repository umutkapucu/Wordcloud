# %% [markdown]
# ## WORDCLOUD
#
# Welcome :)
# Let's import libraries!!

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image 
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Then open the file that we will use (ie. the text file of my CV)

# %%
uk_cv=open('cv_uk.txt', 'r').read()
print ('File opened!')
# Out:
# File opened!

# %% [markdown]
# Need to set stopwords... for further studies, we could add some words in it!!

# %%
my_stopwords = set(STOPWORDS)

# %% [markdown]
# Let's generate the word cloud!

# %%
my_cv_wc = WordCloud(width=2000, height=500, background_color='white', max_words=2000, collocations=False, stopwords=my_stopwords)
my_cv_wc.generate(uk_cv)

fig = plt.figure()
fig.set_figwidth(30) # set width
fig.set_figheight(5) # set height

# display the cloud
plt.imshow(my_cv_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Adding new stopwords!!

# %%
my_stopwords.add('AŞ')
my_stopwords.add('16h')
my_stopwords.add('re')
## whatever needed... :)

print(my_stopwords)
# Out:
# {'up', "hadn't", 'then', "why's", 'no', 'all', 'also', 'com', 'i', 'nor', 'the', 'therefore', 'in', 'once', 'is', 're', 'like', "they've", "i'd", 'what', 'who', 'than', 'very', 'between', "i'm", 'should', 'why', "she'd", "couldn't", 'most', 'ever', "what's", 'how', "we'd", 'those', 'my', "won't", 'yours', 'doing', 'was', "we'll", "when's", 'against', "we're", 'just', "it's", "wouldn't", 'could', 'where', 'having', "you're", "she's", 'ought', "haven't", 'any', 'have', 'at', 'out', 'about', 'AŞ', 'had', 'since', 'into', 'before', 'or', 'yourselves', 'for', 'herself', 'shall', "can't", "you've", "hasn't", '16h', 'some', 'www', 'yourself', 'and', "they'll", 'otherwise', 'were', 'would', 'that', 'further', 'k', 'r', 'more', "i've", "she'll", 'too', 'hers', 'each', 'until', 'cannot', "you'd", 'which', 'own', 'off', 'myself', 'itself', 'we', "how's", 'our', 'from', 'their', "he'll", 'theirs', "here's", 'to', "we've", 'it', 'if', 'such', 'there', 'these', "who's", "i'll", 'am', 'through', 'its', 'both', 'be', 'she', 'under', 'has', "mustn't", 'only', 'over', 'not', 'here', 'him', 'on', 'an', 'by', 'his', 'he', 'ours', 'himself', 'your', 'hence', 'did', 'as', 'themselves', 'because', "wasn't", 'a', 'else', 'being', 'them', "you'll", 'can', 'does', "he's", "he'd", 'after', 'of', "weren't", 'http', 'down', "where's", "shouldn't", "they're", "there's", 'other', 'while', 'her', 'ourselves', "that's", 'are', "let's", 'again', "they'd", "didn't", "isn't", 'me', 'but', 'do', 'same', 'this', 'when', 'whom', 'few', "doesn't", 'during', 'you', 'get', 'with', 'so', 'been', 'above', 'they', "don't", "shan't", "aren't", 'however', 'below'}

# %% [markdown]
# Regenerate wordcloud...

# %%
my_cv_wc = WordCloud(width=2000, height=500, background_color='white', max_words=2000, collocations=True, stopwords=my_stopwords)
my_cv_wc.generate(uk_cv)

fig = plt.figure()
fig.set_figwidth(30) # set width
fig.set_figheight(5) # set height

# display the cloud
plt.imshow(my_cv_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Taaa daaa!
# Let's save the picture as a png file!

# %%
my_cv_wc.to_file('my_cv_wc.png')

# %% [markdown]
# Let's set a mask... I've used a picture of me :)

# %%
wc_mask = np.array(Image.open('uk-nobackground.png'))

plt.imshow(wc_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Yeah! This is me :) Any picture could be used for mask!

# %%
my_cv_wc = WordCloud(width=1000, height=1000, background_color='white', max_words=2000, mask=wc_mask, stopwords=my_stopwords)
my_cv_wc.generate(uk_cv)

fig = plt.figure()
fig.set_figwidth(5) # set width
fig.set_figheight(10) # set height

# display the cloud
plt.imshow(my_cv_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Here we have the masked one!
#
# For detailed information about worldcloud: https://github.com/amueller/word_cloud/
